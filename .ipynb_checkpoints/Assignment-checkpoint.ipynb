# %%
import pandas as pd
import requests
import string
import textstat
import nltk
from io import BytesIO
from bs4 import BeautifulSoup
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
# function for extraction of text from URL
def extract_data_from_url(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            # content selection by class_name & attribute
            content_elements =soup.find_all(class_='td-post-content tagdiv-type') + soup.find_all(attrs={"data-td-block-uid": "tdi_130"})
            content = '\n'.join(element.get_text() for element in content_elements)
            return content
    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
    return None

# %%
def read_words(file_path):
    with open(file_path, 'r') as file:
        words = [word.strip().lower() for word in file.readlines()]
    return words

# %%
def calculate_positive_score(text, positive_words_file):
    positive_words = read_words(positive_words_file)
    words = word_tokenize(text.lower())
    positive_word_count = sum(1 for word in words if word in positive_words)
    total_words = len(words)
    positive_score = (positive_word_count / max(total_words, 1)) * 100
    return positive_score

# %%
def calculate_negative_score(text,negative_words_file):
    negative_words = read_words(negative_words_file) 
    words = word_tokenize(text.lower()) 
    negative_word_count = sum(1 for word in words if word in negative_words)
    total_words = len(words)
    negative_score = (negative_word_count / max(total_words, 1)) * 100
    return negative_score

# %%
def calculate_sentiment_scores(pos_score,neg_score,total_words):
    polarity_score = (pos_score - neg_score) / (pos_score + neg_score + 0.000001)
    subjectivity_score = (pos_score + neg_score) / (total_words + 0.000001)

    return polarity_score, subjectivity_score

# %%
def calculate_avg_word_length(text):
    words = word_tokenize(text.lower())
    total_characters = sum(len(word) for word in words)
    total_words = len(words)
    if total_words > 0:
        avg_word_length = total_characters / total_words
    else:
        avg_word_length = 0
    return avg_word_length

# %%
import re
def calculate_personal_pronouns(text):
    personal_pronouns = ['I', 'we', 'my', 'ours', 'us']
    pronoun_counts = {pronoun.lower(): 0 for pronoun in personal_pronouns}
    pattern = r'\b(?:{})\b(?!S)'.format('|'.join(personal_pronouns))
    matches = re.findall(pattern, text, flags=re.IGNORECASE) # for ignorning 'US' text
    for match in matches:
        pronoun_counts[match.lower()] += 1
    return pronoun_counts

# %%
# Function to calculate text statistics
def calculate_text_statistics(text,positive_words,negative_words):
    if text:
        try:
            sentences = sent_tokenize(text)
            total_sentences = len(sentences)
            words = word_tokenize(text)
            total_words = len(words)
            pos_score = calculate_positive_score(text,positive_words)
            neg_score = calculate_negative_score(text,negative_words)
            polarity_score, subjectivity_score = calculate_sentiment_scores(pos_score,neg_score,total_words)
            return {
                'POSITIVE SCORE': pos_score,
                'NEGATIVE SCORE':neg_score,
                'POLARITY SCORE': polarity_score,
                'SUBJECTIVITY SCORE': subjectivity_score,
                'AVG SENTENCE LENGTH': total_words / max(total_sentences, 1),
                'PERCENTAGE OF COMPLEX WORDS': (textstat.lexicon_count(text, False) / max(total_words, 1)) * 100,
                'FOG INDEX': textstat.gunning_fog(text),
                'AVG NUMBER OF WORDS PER SENTENCE': total_words / max(total_sentences, 1),
                'COMPLEX WORD COUNT': textstat.lexicon_count(text, False),
                'WORD COUNT': total_words,
                'SYLLABLE PER WORD': textstat.syllable_count(text) / max(total_words, 1),
                'PERSONAL PRONOUNS': calculate_personal_pronouns(text),
                'AVG WORD LENGTH': calculate_avg_word_length(text)
            }
        except Exception as e:
            print(f"Error calculating text statistics: {e}")
    return {}

# %%
# function for clean file with the help of stop_words files
def load_stop_words(file_paths):
    stop_words = set()
    for file_path in file_paths:
        with open(file_path, 'r') as file:
            words = file.read().splitlines()
            stop_words.update(words)
    return stop_words
def clean_text(text, stop_words):
    words = text.split()
    words = [word.strip(string.punctuation) for word in words]
    filtered_words = [word for word in words if word.lower() not in stop_words]
    cleaned_text = ' '.join(filtered_words)
    return cleaned_text
stop_words_files = ['StopWords/StopWords_Auditor.txt', 
                    'StopWords/StopWords_Currencies.txt',
                    'StopWords/StopWords_DatesandNumbers.txt', 
                    'StopWords/StopWords_Generic.txt', 
                    'StopWords/StopWords_GenericLong.txt', 
                    'StopWords/StopWords_Geographic.txt', 
                    'StopWords/StopWords_Names.txt']
stop_words = load_stop_words(stop_words_files)
cleaned_text = clean_text(text, stop_words)

# %%
#main code block
#code for import file and export resultant file(Output_Data_Structure.xlsx)

excel_url = 'Input.xlsx'
positive_words='positive-words.txt'
negative_words='negative-words.txt'
excel_data = pd.read_excel(excel_url)
new_data = pd.DataFrame(columns=[
    'URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
    'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH', 'PERCENTAGE OF COMPLEX WORDS',
    'FOG INDEX', 'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT',
    'WORD COUNT', 'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'
])
i=0
for index, row in excel_data.iterrows():
    url = row['URL']
    url_id = row['URL_ID']
    data = extract_data_from_url(url)
    if data:
        i=0
        i=i+1
        stop_words = load_stop_words(stop_words_files)
        cleaned_text = clean_text(data, stop_words)
        
        statistics = calculate_text_statistics(cleaned_text,positive_words,negative_words)
        extracted_data = {
            'URL_ID': url_id,
            'URL': url,
            **statistics,
        }
        new_data = pd.concat([new_data, pd.DataFrame([extracted_data])], ignore_index=True)
new_excel_file = 'Output_Data_Structure.xlsx'
new_data.to_excel(new_excel_file, index=False)
print(f"Data saved to {new_excel_file}")
# Out:
# 1
# {'URL_ID': 'blackassign0001', 'URL': 'https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/', 'POSITIVE SCORE': 5.86145648312611, 'NEGATIVE SCORE': 1.0657193605683837, 'POLARITY SCORE': 0.6923075923668783, 'SUBJECTIVITY SCORE': 0.012304042329290322, 'AVG SENTENCE LENGTH': 563.0, 'PERCENTAGE OF COMPLEX WORDS': 99.28952042628775, 'FOG INDEX': 116.09, 'AVG NUMBER OF WORDS PER SENTENCE': 563.0, 'COMPLEX WORD COUNT': 559, 'WORD COUNT': 563, 'SYLLABLE PER WORD': 1.9573712255772646, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.525754884547069}
# 2
# {'URL_ID': 'blackassign0002', 'URL': 'https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/', 'POSITIVE SCORE': 7.290400972053463, 'NEGATIVE SCORE': 3.766707168894289, 'POLARITY SCORE': 0.31868128985992294, 'SUBJECTIVITY SCORE': 0.013435125306819715, 'AVG SENTENCE LENGTH': 823.0, 'PERCENTAGE OF COMPLEX WORDS': 96.35479951397326, 'FOG INDEX': 115.0, 'AVG NUMBER OF WORDS PER SENTENCE': 823.0, 'COMPLEX WORD COUNT': 793, 'WORD COUNT': 823, 'SYLLABLE PER WORD': 2.2029161603888214, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 2}, 'AVG WORD LENGTH': 7.195625759416768}
# 3
# {'URL_ID': 'blackassign0003', 'URL': 'https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/', 'POSITIVE SCORE': 6.050955414012739, 'NEGATIVE SCORE': 3.821656050955414, 'POLARITY SCORE': 0.22580642874089724, 'SUBJECTIVITY SCORE': 0.015720718868228397, 'AVG SENTENCE LENGTH': 628.0, 'PERCENTAGE OF COMPLEX WORDS': 99.04458598726114, 'FOG INDEX': 258.45, 'AVG NUMBER OF WORDS PER SENTENCE': 628.0, 'COMPLEX WORD COUNT': 622, 'WORD COUNT': 628, 'SYLLABLE PER WORD': 2.6369426751592355, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 8.23407643312102}
# 4
# {'URL_ID': 'blackassign0004', 'URL': 'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/', 'POSITIVE SCORE': 6.089743589743589, 'NEGATIVE SCORE': 12.01923076923077, 'POLARITY SCORE': -0.3274336102372945, 'SUBJECTIVITY SCORE': 0.029020792195438405, 'AVG SENTENCE LENGTH': 624.0, 'PERCENTAGE OF COMPLEX WORDS': 98.3974358974359, 'FOG INDEX': 256.74, 'AVG NUMBER OF WORDS PER SENTENCE': 624.0, 'COMPLEX WORD COUNT': 614, 'WORD COUNT': 624, 'SYLLABLE PER WORD': 2.511217948717949, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.953525641025641}
# 5
# {'URL_ID': 'blackassign0005', 'URL': 'https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/', 'POSITIVE SCORE': 5.866666666666666, 'NEGATIVE SCORE': 2.1333333333333333, 'POLARITY SCORE': 0.4666666083333406, 'SUBJECTIVITY SCORE': 0.021333333276444443, 'AVG SENTENCE LENGTH': 375.0, 'PERCENTAGE OF COMPLEX WORDS': 98.66666666666667, 'FOG INDEX': 83.73, 'AVG NUMBER OF WORDS PER SENTENCE': 375.0, 'COMPLEX WORD COUNT': 370, 'WORD COUNT': 375, 'SYLLABLE PER WORD': 2.2106666666666666, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.464}
# 6
# {'URL_ID': 'blackassign0006', 'URL': 'https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/', 'POSITIVE SCORE': 7.887579329102448, 'NEGATIVE SCORE': 2.447869446962829, 'POLARITY SCORE': 0.5263157385503281, 'SUBJECTIVITY SCORE': 0.009370307132089728, 'AVG SENTENCE LENGTH': 1103.0, 'PERCENTAGE OF COMPLEX WORDS': 98.6400725294651, 'FOG INDEX': 153.19, 'AVG NUMBER OF WORDS PER SENTENCE': 1103.0, 'COMPLEX WORD COUNT': 1088, 'WORD COUNT': 1103, 'SYLLABLE PER WORD': 2.3653671804170444, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.850407978241161}
# 7
# {'URL_ID': 'blackassign0007', 'URL': 'https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/', 'POSITIVE SCORE': 4.456824512534819, 'NEGATIVE SCORE': 9.749303621169917, 'POLARITY SCORE': -0.372548993383316, 'SUBJECTIVITY SCORE': 0.01978569375197638, 'AVG SENTENCE LENGTH': 718.0, 'PERCENTAGE OF COMPLEX WORDS': 97.63231197771589, 'FOG INDEX': 288.34, 'AVG NUMBER OF WORDS PER SENTENCE': 718.0, 'COMPLEX WORD COUNT': 701, 'WORD COUNT': 718, 'SYLLABLE PER WORD': 2.16016713091922, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.044568245125348}
# 8
# {'URL_ID': 'blackassign0008', 'URL': 'https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/', 'POSITIVE SCORE': 6.185567010309279, 'NEGATIVE SCORE': 1.8556701030927836, 'POLARITY SCORE': 0.5384614714990222, 'SUBJECTIVITY SCORE': 0.016579870302726167, 'AVG SENTENCE LENGTH': 485.0, 'PERCENTAGE OF COMPLEX WORDS': 99.58762886597938, 'FOG INDEX': 203.8, 'AVG NUMBER OF WORDS PER SENTENCE': 485.0, 'COMPLEX WORD COUNT': 483, 'WORD COUNT': 485, 'SYLLABLE PER WORD': 2.6144329896907217, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 8.117525773195876}
# 9
# {'URL_ID': 'blackassign0009', 'URL': 'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/', 'POSITIVE SCORE': 6.260296540362438, 'NEGATIVE SCORE': 8.40197693574959, 'POLARITY SCORE': -0.14606740576821187, 'SUBJECTIVITY SCORE': 0.024155310464508594, 'AVG SENTENCE LENGTH': 607.0, 'PERCENTAGE OF COMPLEX WORDS': 99.01153212520593, 'FOG INDEX': 247.8, 'AVG NUMBER OF WORDS PER SENTENCE': 607.0, 'COMPLEX WORD COUNT': 601, 'WORD COUNT': 607, 'SYLLABLE PER WORD': 2.5831960461285006, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 8.069192751235585}
# 10
# {'URL_ID': 'blackassign0010', 'URL': 'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/', 'POSITIVE SCORE': 7.5388026607538805, 'NEGATIVE SCORE': 10.033259423503326, 'POLARITY SCORE': -0.1419558278836494, 'SUBJECTIVITY SCORE': 0.009740610906051326, 'AVG SENTENCE LENGTH': 1804.0, 'PERCENTAGE OF COMPLEX WORDS': 98.22616407982262, 'FOG INDEX': 241.86, 'AVG NUMBER OF WORDS PER SENTENCE': 1804.0, 'COMPLEX WORD COUNT': 1772, 'WORD COUNT': 1804, 'SYLLABLE PER WORD': 2.4262749445676275, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.7682926829268295}
# 11
# {'URL_ID': 'blackassign0011', 'URL': 'https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/', 'POSITIVE SCORE': 7.281553398058252, 'NEGATIVE SCORE': 2.4271844660194173, 'POLARITY SCORE': 0.49999994850000534, 'SUBJECTIVITY SCORE': 0.01178244884987284, 'AVG SENTENCE LENGTH': 824.0, 'PERCENTAGE OF COMPLEX WORDS': 98.66504854368931, 'FOG INDEX': 334.84, 'AVG NUMBER OF WORDS PER SENTENCE': 824.0, 'COMPLEX WORD COUNT': 813, 'WORD COUNT': 824, 'SYLLABLE PER WORD': 2.4733009708737863, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.771844660194175}
# 12
# {'URL_ID': 'blackassign0012', 'URL': 'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/', 'POSITIVE SCORE': 9.163802978235967, 'NEGATIVE SCORE': 2.7491408934707904, 'POLARITY SCORE': 0.5384614932618381, 'SUBJECTIVITY SCORE': 0.013645983800756902, 'AVG SENTENCE LENGTH': 873.0, 'PERCENTAGE OF COMPLEX WORDS': 97.709049255441, 'FOG INDEX': 53.59, 'AVG NUMBER OF WORDS PER SENTENCE': 873.0, 'COMPLEX WORD COUNT': 853, 'WORD COUNT': 873, 'SYLLABLE PER WORD': 2.080183276059565, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.676975945017182}
# 13
# {'URL_ID': 'blackassign0013', 'URL': 'https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/', 'POSITIVE SCORE': 13.194444444444445, 'NEGATIVE SCORE': 4.513888888888888, 'POLARITY SCORE': 0.4901960507497133, 'SUBJECTIVITY SCORE': 0.061487268305021055, 'AVG SENTENCE LENGTH': 288.0, 'PERCENTAGE OF COMPLEX WORDS': 100.0, 'FOG INDEX': 124.92, 'AVG NUMBER OF WORDS PER SENTENCE': 288.0, 'COMPLEX WORD COUNT': 288, 'WORD COUNT': 288, 'SYLLABLE PER WORD': 2.4097222222222223, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 8.097222222222221}
# 14
# {'URL_ID': 'blackassign0014', 'URL': 'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/', 'POSITIVE SCORE': 3.7701974865350087, 'NEGATIVE SCORE': 4.847396768402154, 'POLARITY SCORE': -0.12499998549479337, 'SUBJECTIVITY SCORE': 0.015471443876958204, 'AVG SENTENCE LENGTH': 557.0, 'PERCENTAGE OF COMPLEX WORDS': 98.38420107719928, 'FOG INDEX': 43.6, 'AVG NUMBER OF WORDS PER SENTENCE': 557.0, 'COMPLEX WORD COUNT': 548, 'WORD COUNT': 557, 'SYLLABLE PER WORD': 2.1256732495511668, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.242369838420108}
# 15
# {'URL_ID': 'blackassign0015', 'URL': 'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/', 'POSITIVE SCORE': 5.154639175257731, 'NEGATIVE SCORE': 3.9764359351988214, 'POLARITY SCORE': 0.12903224393340426, 'SUBJECTIVITY SCORE': 0.013447827830646134, 'AVG SENTENCE LENGTH': 679.0, 'PERCENTAGE OF COMPLEX WORDS': 97.05449189985272, 'FOG INDEX': 74.3, 'AVG NUMBER OF WORDS PER SENTENCE': 679.0, 'COMPLEX WORD COUNT': 659, 'WORD COUNT': 679, 'SYLLABLE PER WORD': 2.0795287187039766, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.248895434462445}
# 16
# {'URL_ID': 'blackassign0016', 'URL': 'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/', 'POSITIVE SCORE': 5.154639175257731, 'NEGATIVE SCORE': 3.9764359351988214, 'POLARITY SCORE': 0.12903224393340426, 'SUBJECTIVITY SCORE': 0.013447827830646134, 'AVG SENTENCE LENGTH': 679.0, 'PERCENTAGE OF COMPLEX WORDS': 97.05449189985272, 'FOG INDEX': 74.3, 'AVG NUMBER OF WORDS PER SENTENCE': 679.0, 'COMPLEX WORD COUNT': 659, 'WORD COUNT': 679, 'SYLLABLE PER WORD': 2.0795287187039766, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.248895434462445}
# 17
# {'URL_ID': 'blackassign0017', 'URL': 'https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/', 'POSITIVE SCORE': 7.6190476190476195, 'NEGATIVE SCORE': 1.9047619047619049, 'POLARITY SCORE': 0.5999999370000066, 'SUBJECTIVITY SCORE': 0.015117157950305342, 'AVG SENTENCE LENGTH': 630.0, 'PERCENTAGE OF COMPLEX WORDS': 97.46031746031746, 'FOG INDEX': 70.13, 'AVG NUMBER OF WORDS PER SENTENCE': 630.0, 'COMPLEX WORD COUNT': 614, 'WORD COUNT': 630, 'SYLLABLE PER WORD': 2.168253968253968, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 1}, 'AVG WORD LENGTH': 7.20952380952381}
# 18
# {'URL_ID': 'blackassign0018', 'URL': 'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/', 'POSITIVE SCORE': 5.68561872909699, 'NEGATIVE SCORE': 1.6722408026755853, 'POLARITY SCORE': 0.5454544713223242, 'SUBJECTIVITY SCORE': 0.012304112908810137, 'AVG SENTENCE LENGTH': 598.0, 'PERCENTAGE OF COMPLEX WORDS': 95.15050167224081, 'FOG INDEX': 48.32, 'AVG NUMBER OF WORDS PER SENTENCE': 598.0, 'COMPLEX WORD COUNT': 569, 'WORD COUNT': 598, 'SYLLABLE PER WORD': 2.1555183946488294, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.369565217391305}
# 19
# {'URL_ID': 'blackassign0019', 'URL': 'https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/', 'POSITIVE SCORE': 6.805708013172337, 'NEGATIVE SCORE': 0.6586169045005488, 'POLARITY SCORE': 0.823529301436001, 'SUBJECTIVITY SCORE': 0.008193550943446032, 'AVG SENTENCE LENGTH': 911.0, 'PERCENTAGE OF COMPLEX WORDS': 95.27991218441272, 'FOG INDEX': 122.86, 'AVG NUMBER OF WORDS PER SENTENCE': 911.0, 'COMPLEX WORD COUNT': 868, 'WORD COUNT': 911, 'SYLLABLE PER WORD': 2.1514818880351263, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.226125137211855}
# 20
# {'URL_ID': 'blackassign0020', 'URL': 'https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/', 'POSITIVE SCORE': 3.3472803347280333, 'NEGATIVE SCORE': 0.0, 'POLARITY SCORE': 0.9999997012500892, 'SUBJECTIVITY SCORE': 0.01400535699047145, 'AVG SENTENCE LENGTH': 239.0, 'PERCENTAGE OF COMPLEX WORDS': 89.5397489539749, 'FOG INDEX': 47.66, 'AVG NUMBER OF WORDS PER SENTENCE': 239.0, 'COMPLEX WORD COUNT': 214, 'WORD COUNT': 239, 'SYLLABLE PER WORD': 1.9832635983263598, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.7154811715481175}
# 21
# {'URL_ID': 'blackassign0021', 'URL': 'https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/', 'POSITIVE SCORE': 4.174228675136116, 'NEGATIVE SCORE': 8.348457350272232, 'POLARITY SCORE': -0.333333306714978, 'SUBJECTIVITY SCORE': 0.022727197827007533, 'AVG SENTENCE LENGTH': 551.0, 'PERCENTAGE OF COMPLEX WORDS': 96.55172413793103, 'FOG INDEX': 79.42, 'AVG NUMBER OF WORDS PER SENTENCE': 551.0, 'COMPLEX WORD COUNT': 532, 'WORD COUNT': 551, 'SYLLABLE PER WORD': 2.2286751361161525, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.344827586206897}
# 22
# {'URL_ID': 'blackassign0022', 'URL': 'https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/', 'POSITIVE SCORE': 7.103825136612022, 'NEGATIVE SCORE': 5.46448087431694, 'POLARITY SCORE': 0.13043477223062466, 'SUBJECTIVITY SCORE': 0.06867926744398739, 'AVG SENTENCE LENGTH': 183.0, 'PERCENTAGE OF COMPLEX WORDS': 98.90710382513662, 'FOG INDEX': 44.38, 'AVG NUMBER OF WORDS PER SENTENCE': 183.0, 'COMPLEX WORD COUNT': 181, 'WORD COUNT': 183, 'SYLLABLE PER WORD': 2.202185792349727, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.174863387978142}
# 23
# {'URL_ID': 'blackassign0023', 'URL': 'https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/', 'POSITIVE SCORE': 4.3604651162790695, 'NEGATIVE SCORE': 2.3255813953488373, 'POLARITY SCORE': 0.3043477805671145, 'SUBJECTIVITY SCORE': 0.009718090845799152, 'AVG SENTENCE LENGTH': 344.0, 'PERCENTAGE OF COMPLEX WORDS': 97.96511627906976, 'FOG INDEX': 60.79, 'AVG NUMBER OF WORDS PER SENTENCE': 344.0, 'COMPLEX WORD COUNT': 674, 'WORD COUNT': 688, 'SYLLABLE PER WORD': 2.0290697674418605, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.824127906976744}
# 24
# {'URL_ID': 'blackassign0024', 'URL': 'https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/', 'POSITIVE SCORE': 7.6158940397351, 'NEGATIVE SCORE': 0.9933774834437087, 'POLARITY SCORE': 0.7692306798816673, 'SUBJECTIVITY SCORE': 0.028507521505534063, 'AVG SENTENCE LENGTH': 302.0, 'PERCENTAGE OF COMPLEX WORDS': 98.01324503311258, 'FOG INDEX': 38.92, 'AVG NUMBER OF WORDS PER SENTENCE': 302.0, 'COMPLEX WORD COUNT': 296, 'WORD COUNT': 302, 'SYLLABLE PER WORD': 2.0860927152317883, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.990066225165563}
# 25
# {'URL_ID': 'blackassign0025', 'URL': 'https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/', 'POSITIVE SCORE': 3.473491773308958, 'NEGATIVE SCORE': 2.010968921389397, 'POLARITY SCORE': 0.2666666180444533, 'SUBJECTIVITY SCORE': 0.010026436352233853, 'AVG SENTENCE LENGTH': 547.0, 'PERCENTAGE OF COMPLEX WORDS': 93.41864716636198, 'FOG INDEX': 17.76, 'AVG NUMBER OF WORDS PER SENTENCE': 547.0, 'COMPLEX WORD COUNT': 511, 'WORD COUNT': 547, 'SYLLABLE PER WORD': 1.776965265082267, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.093235831809872}
# 26
# {'URL_ID': 'blackassign0026', 'URL': 'https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/', 'POSITIVE SCORE': 4.563492063492063, 'NEGATIVE SCORE': 2.7777777777777777, 'POLARITY SCORE': 0.24324321010957353, 'SUBJECTIVITY SCORE': 0.014566011560920297, 'AVG SENTENCE LENGTH': 504.0, 'PERCENTAGE OF COMPLEX WORDS': 96.62698412698413, 'FOG INDEX': 32.74, 'AVG NUMBER OF WORDS PER SENTENCE': 504.0, 'COMPLEX WORD COUNT': 487, 'WORD COUNT': 504, 'SYLLABLE PER WORD': 2.0357142857142856, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.773809523809524}
# 27
# {'URL_ID': 'blackassign0027', 'URL': 'https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/', 'POSITIVE SCORE': 4.508856682769726, 'NEGATIVE SCORE': 4.186795491143317, 'POLARITY SCORE': 0.037037032777778235, 'SUBJECTIVITY SCORE': 0.014002660482947476, 'AVG SENTENCE LENGTH': 621.0, 'PERCENTAGE OF COMPLEX WORDS': 95.16908212560386, 'FOG INDEX': 84.99, 'AVG NUMBER OF WORDS PER SENTENCE': 621.0, 'COMPLEX WORD COUNT': 591, 'WORD COUNT': 621, 'SYLLABLE PER WORD': 1.827697262479871, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.223832528180354}
# 28
# {'URL_ID': 'blackassign0028', 'URL': 'https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/', 'POSITIVE SCORE': 5.8626465661641545, 'NEGATIVE SCORE': 4.355108877721943, 'POLARITY SCORE': 0.1475409691668921, 'SUBJECTIVITY SCORE': 0.017115168219046784, 'AVG SENTENCE LENGTH': 597.0, 'PERCENTAGE OF COMPLEX WORDS': 94.13735343383584, 'FOG INDEX': 29.91, 'AVG NUMBER OF WORDS PER SENTENCE': 597.0, 'COMPLEX WORD COUNT': 562, 'WORD COUNT': 597, 'SYLLABLE PER WORD': 2.030150753768844, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 1}, 'AVG WORD LENGTH': 7.100502512562814}
# 29
# {'URL_ID': 'blackassign0029', 'URL': 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/', 'POSITIVE SCORE': 6.267806267806268, 'NEGATIVE SCORE': 3.2288698955365627, 'POLARITY SCORE': 0.31999996630400357, 'SUBJECTIVITY SCORE': 0.009018685806575635, 'AVG SENTENCE LENGTH': 1053.0, 'PERCENTAGE OF COMPLEX WORDS': 97.43589743589743, 'FOG INDEX': 214.75, 'AVG NUMBER OF WORDS PER SENTENCE': 1053.0, 'COMPLEX WORD COUNT': 1026, 'WORD COUNT': 1053, 'SYLLABLE PER WORD': 2.2108262108262107, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.322886989553656}
# 30
# {'URL_ID': 'blackassign0030', 'URL': 'https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/', 'POSITIVE SCORE': 8.955223880597014, 'NEGATIVE SCORE': 5.6716417910447765, 'POLARITY SCORE': 0.22448978057059657, 'SUBJECTIVITY SCORE': 0.021831142760911415, 'AVG SENTENCE LENGTH': 670.0, 'PERCENTAGE OF COMPLEX WORDS': 93.88059701492537, 'FOG INDEX': 133.69, 'AVG NUMBER OF WORDS PER SENTENCE': 670.0, 'COMPLEX WORD COUNT': 629, 'WORD COUNT': 670, 'SYLLABLE PER WORD': 1.9194029850746268, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.419402985074627}
# 31
# {'URL_ID': 'blackassign0031', 'URL': 'https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/', 'POSITIVE SCORE': 7.357859531772576, 'NEGATIVE SCORE': 4.23634336677815, 'POLARITY SCORE': 0.2692307460096174, 'SUBJECTIVITY SCORE': 0.012925532759894307, 'AVG SENTENCE LENGTH': 897.0, 'PERCENTAGE OF COMPLEX WORDS': 97.54738015607582, 'FOG INDEX': 359.44, 'AVG NUMBER OF WORDS PER SENTENCE': 897.0, 'COMPLEX WORD COUNT': 875, 'WORD COUNT': 897, 'SYLLABLE PER WORD': 2.2675585284280935, 'PERSONAL PRONOUNS': {'i': 0, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.36231884057971}
# 32
# {'URL_ID': 'blackassign0032', 'URL': 'https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/', 'POSITIVE SCORE': 9.324324324324325, 'NEGATIVE SCORE': 3.783783783783784, 'POLARITY SCORE': 0.4226803801254143, 'SUBJECTIVITY SCORE': 0.01771365958161412, 'AVG SENTENCE LENGTH': 740.0, 'PERCENTAGE OF COMPLEX WORDS': 98.37837837837839, 'FOG INDEX': 151.55, 'AVG NUMBER OF WORDS PER SENTENCE': 740.0, 'COMPLEX WORD COUNT': 728, 'WORD COUNT': 740, 'SYLLABLE PER WORD': 2.0081081081081082, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.597297297297297}
# 33
# {'URL_ID': 'blackassign0033', 'URL': 'https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/', 'POSITIVE SCORE': 6.6815144766147, 'NEGATIVE SCORE': 2.783964365256125, 'POLARITY SCORE': 0.4117646623806274, 'SUBJECTIVITY SCORE': 0.010540622306603789, 'AVG SENTENCE LENGTH': 898.0, 'PERCENTAGE OF COMPLEX WORDS': 94.09799554565701, 'FOG INDEX': 42.23, 'AVG NUMBER OF WORDS PER SENTENCE': 898.0, 'COMPLEX WORD COUNT': 845, 'WORD COUNT': 898, 'SYLLABLE PER WORD': 2.0345211581291758, 'PERSONAL PRONOUNS': {'i': 0, 'we': 2, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.740534521158129}
# 34
# {'URL_ID': 'blackassign0034', 'URL': 'https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/', 'POSITIVE SCORE': 7.064364207221351, 'NEGATIVE SCORE': 3.610675039246468, 'POLARITY SCORE': 0.32352938145761534, 'SUBJECTIVITY SCORE': 0.016758303343343037, 'AVG SENTENCE LENGTH': 637.0, 'PERCENTAGE OF COMPLEX WORDS': 94.19152276295134, 'FOG INDEX': 88.83, 'AVG NUMBER OF WORDS PER SENTENCE': 637.0, 'COMPLEX WORD COUNT': 600, 'WORD COUNT': 637, 'SYLLABLE PER WORD': 2.020408163265306, 'PERSONAL PRONOUNS': {'i': 2, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.7032967032967035}
# 35
# {'URL_ID': 'blackassign0035', 'URL': 'https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/', 'POSITIVE SCORE': 7.222222222222221, 'NEGATIVE SCORE': 3.3333333333333335, 'POLARITY SCORE': 0.3684210177285351, 'SUBJECTIVITY SCORE': 0.0293209875728738, 'AVG SENTENCE LENGTH': 360.0, 'PERCENTAGE OF COMPLEX WORDS': 98.88888888888889, 'FOG INDEX': 55.79, 'AVG NUMBER OF WORDS PER SENTENCE': 360.0, 'COMPLEX WORD COUNT': 356, 'WORD COUNT': 360, 'SYLLABLE PER WORD': 2.111111111111111, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.919444444444444}
# 36
# 37
# {'URL_ID': 'blackassign0037', 'URL': 'https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/', 'POSITIVE SCORE': 9.947643979057592, 'NEGATIVE SCORE': 3.4031413612565444, 'POLARITY SCORE': 0.4901960417147279, 'SUBJECTIVITY SCORE': 0.03494969975226292, 'AVG SENTENCE LENGTH': 382.0, 'PERCENTAGE OF COMPLEX WORDS': 92.67015706806284, 'FOG INDEX': 76.68, 'AVG NUMBER OF WORDS PER SENTENCE': 382.0, 'COMPLEX WORD COUNT': 354, 'WORD COUNT': 382, 'SYLLABLE PER WORD': 1.8036649214659686, 'PERSONAL PRONOUNS': {'i': 0, 'we': 2, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.172774869109948}
# 38
# {'URL_ID': 'blackassign0038', 'URL': 'https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/', 'POSITIVE SCORE': 6.25, 'NEGATIVE SCORE': 3.824626865671642, 'POLARITY SCORE': 0.24074071684499554, 'SUBJECTIVITY SCORE': 0.009397972813688123, 'AVG SENTENCE LENGTH': 1072.0, 'PERCENTAGE OF COMPLEX WORDS': 94.40298507462687, 'FOG INDEX': 75.35, 'AVG NUMBER OF WORDS PER SENTENCE': 1072.0, 'COMPLEX WORD COUNT': 1012, 'WORD COUNT': 1072, 'SYLLABLE PER WORD': 2.013059701492537, 'PERSONAL PRONOUNS': {'i': 1, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.545708955223881}
# 39
# {'URL_ID': 'blackassign0039', 'URL': 'https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/', 'POSITIVE SCORE': 4.2408821034775235, 'NEGATIVE SCORE': 5.767599660729432, 'POLARITY SCORE': -0.15254235764004748, 'SUBJECTIVITY SCORE': 0.008488958232161151, 'AVG SENTENCE LENGTH': 1179.0, 'PERCENTAGE OF COMPLEX WORDS': 88.29516539440203, 'FOG INDEX': 40.56, 'AVG NUMBER OF WORDS PER SENTENCE': 1179.0, 'COMPLEX WORD COUNT': 1041, 'WORD COUNT': 1179, 'SYLLABLE PER WORD': 1.81509754028838, 'PERSONAL PRONOUNS': {'i': 0, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.139949109414759}
# 40
# {'URL_ID': 'blackassign0040', 'URL': 'https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/', 'POSITIVE SCORE': 5.7507987220447285, 'NEGATIVE SCORE': 3.5143769968051117, 'POLARITY SCORE': 0.2413792842925118, 'SUBJECTIVITY SCORE': 0.014800600166212843, 'AVG SENTENCE LENGTH': 626.0, 'PERCENTAGE OF COMPLEX WORDS': 97.92332268370608, 'FOG INDEX': 254.14, 'AVG NUMBER OF WORDS PER SENTENCE': 626.0, 'COMPLEX WORD COUNT': 613, 'WORD COUNT': 626, 'SYLLABLE PER WORD': 2.2955271565495208, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.559105431309904}
# 41
# {'URL_ID': 'blackassign0041', 'URL': 'https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/', 'POSITIVE SCORE': 4.525547445255475, 'NEGATIVE SCORE': 4.233576642335766, 'POLARITY SCORE': 0.033333329527778274, 'SUBJECTIVITY SCORE': 0.012787042444969633, 'AVG SENTENCE LENGTH': 685.0, 'PERCENTAGE OF COMPLEX WORDS': 93.86861313868613, 'FOG INDEX': 44.34, 'AVG NUMBER OF WORDS PER SENTENCE': 685.0, 'COMPLEX WORD COUNT': 643, 'WORD COUNT': 685, 'SYLLABLE PER WORD': 1.9197080291970803, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.327007299270073}
# 42
# {'URL_ID': 'blackassign0042', 'URL': 'https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/', 'POSITIVE SCORE': 8.835341365461847, 'NEGATIVE SCORE': 3.2128514056224895, 'POLARITY SCORE': 0.4666666279333367, 'SUBJECTIVITY SCORE': 0.016128772094987368, 'AVG SENTENCE LENGTH': 747.0, 'PERCENTAGE OF COMPLEX WORDS': 94.77911646586345, 'FOG INDEX': 24.83, 'AVG NUMBER OF WORDS PER SENTENCE': 747.0, 'COMPLEX WORD COUNT': 708, 'WORD COUNT': 747, 'SYLLABLE PER WORD': 2.145917001338688, 'PERSONAL PRONOUNS': {'i': 11, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.937081659973226}
# 43
# {'URL_ID': 'blackassign0043', 'URL': 'https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/', 'POSITIVE SCORE': 8.505747126436782, 'NEGATIVE SCORE': 2.7586206896551726, 'POLARITY SCORE': 0.5102040363390294, 'SUBJECTIVITY SCORE': 0.012947549199016558, 'AVG SENTENCE LENGTH': 870.0, 'PERCENTAGE OF COMPLEX WORDS': 94.82758620689656, 'FOG INDEX': 73.94, 'AVG NUMBER OF WORDS PER SENTENCE': 870.0, 'COMPLEX WORD COUNT': 825, 'WORD COUNT': 870, 'SYLLABLE PER WORD': 2.0229885057471266, 'PERSONAL PRONOUNS': {'i': 0, 'we': 2, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.57816091954023}
# 44
# {'URL_ID': 'blackassign0044', 'URL': 'https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/', 'POSITIVE SCORE': 9.558823529411764, 'NEGATIVE SCORE': 0.0, 'POLARITY SCORE': 0.9999998953846264, 'SUBJECTIVITY SCORE': 0.03514273343481261, 'AVG SENTENCE LENGTH': 272.0, 'PERCENTAGE OF COMPLEX WORDS': 99.26470588235294, 'FOG INDEX': 116.89, 'AVG NUMBER OF WORDS PER SENTENCE': 272.0, 'COMPLEX WORD COUNT': 270, 'WORD COUNT': 272, 'SYLLABLE PER WORD': 2.2205882352941178, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.452205882352941}
# 45
# {'URL_ID': 'blackassign0045', 'URL': 'https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/', 'POSITIVE SCORE': 9.575757575757576, 'NEGATIVE SCORE': 4.7272727272727275, 'POLARITY SCORE': 0.3389830271473731, 'SUBJECTIVITY SCORE': 0.017337006406900966, 'AVG SENTENCE LENGTH': 825.0, 'PERCENTAGE OF COMPLEX WORDS': 93.45454545454545, 'FOG INDEX': 316.13, 'AVG NUMBER OF WORDS PER SENTENCE': 825.0, 'COMPLEX WORD COUNT': 771, 'WORD COUNT': 825, 'SYLLABLE PER WORD': 1.9248484848484848, 'PERSONAL PRONOUNS': {'i': 0, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.406060606060606}
# 46
# {'URL_ID': 'blackassign0046', 'URL': 'https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/', 'POSITIVE SCORE': 5.454545454545454, 'NEGATIVE SCORE': 0.0, 'POLARITY SCORE': 0.9999998166667002, 'SUBJECTIVITY SCORE': 0.011019283724295293, 'AVG SENTENCE LENGTH': 495.0, 'PERCENTAGE OF COMPLEX WORDS': 96.96969696969697, 'FOG INDEX': 102.56, 'AVG NUMBER OF WORDS PER SENTENCE': 495.0, 'COMPLEX WORD COUNT': 480, 'WORD COUNT': 495, 'SYLLABLE PER WORD': 2.107070707070707, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.91919191919192}
# 47
# {'URL_ID': 'blackassign0047', 'URL': 'https://insights.blackcoffer.com/evolution-of-advertising-industry/', 'POSITIVE SCORE': 3.6553524804177546, 'NEGATIVE SCORE': 1.5665796344647518, 'POLARITY SCORE': 0.3999999234000147, 'SUBJECTIVITY SCORE': 0.01363428747062198, 'AVG SENTENCE LENGTH': 383.0, 'PERCENTAGE OF COMPLEX WORDS': 98.17232375979113, 'FOG INDEX': 158.27, 'AVG NUMBER OF WORDS PER SENTENCE': 383.0, 'COMPLEX WORD COUNT': 376, 'WORD COUNT': 383, 'SYLLABLE PER WORD': 2.339425587467363, 'PERSONAL PRONOUNS': {'i': 0, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.631853785900783}
# 48
# {'URL_ID': 'blackassign0048', 'URL': 'https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/', 'POSITIVE SCORE': 1.9736842105263157, 'NEGATIVE SCORE': 2.631578947368421, 'POLARITY SCORE': -0.1428571118367414, 'SUBJECTIVITY SCORE': 0.030297783734190478, 'AVG SENTENCE LENGTH': 152.0, 'PERCENTAGE OF COMPLEX WORDS': 98.02631578947368, 'FOG INDEX': 68.19, 'AVG NUMBER OF WORDS PER SENTENCE': 152.0, 'COMPLEX WORD COUNT': 149, 'WORD COUNT': 152, 'SYLLABLE PER WORD': 2.2039473684210527, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.177631578947368}
# 49
# 50
# {'URL_ID': 'blackassign0050', 'URL': 'https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/', 'POSITIVE SCORE': 3.418803418803419, 'NEGATIVE SCORE': 9.971509971509972, 'POLARITY SCORE': -0.48936166558171396, 'SUBJECTIVITY SCORE': 0.019074520471850244, 'AVG SENTENCE LENGTH': 702.0, 'PERCENTAGE OF COMPLEX WORDS': 97.86324786324786, 'FOG INDEX': 98.71, 'AVG NUMBER OF WORDS PER SENTENCE': 702.0, 'COMPLEX WORD COUNT': 687, 'WORD COUNT': 702, 'SYLLABLE PER WORD': 2.0242165242165244, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.89031339031339}
# 51
# {'URL_ID': 'blackassign0051', 'URL': 'https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/', 'POSITIVE SCORE': 4.829545454545454, 'NEGATIVE SCORE': 4.261363636363636, 'POLARITY SCORE': 0.062499993125000784, 'SUBJECTIVITY SCORE': 0.02582644620762115, 'AVG SENTENCE LENGTH': 352.0, 'PERCENTAGE OF COMPLEX WORDS': 100.0, 'FOG INDEX': 43.95, 'AVG NUMBER OF WORDS PER SENTENCE': 352.0, 'COMPLEX WORD COUNT': 352, 'WORD COUNT': 352, 'SYLLABLE PER WORD': 2.0482954545454546, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.840909090909091}
# 52
# {'URL_ID': 'blackassign0052', 'URL': 'https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/', 'POSITIVE SCORE': 6.76779463243874, 'NEGATIVE SCORE': 4.434072345390899, 'POLARITY SCORE': 0.20833331473524472, 'SUBJECTIVITY SCORE': 0.013071023296101068, 'AVG SENTENCE LENGTH': 857.0, 'PERCENTAGE OF COMPLEX WORDS': 96.03267211201867, 'FOG INDEX': 335.76, 'AVG NUMBER OF WORDS PER SENTENCE': 857.0, 'COMPLEX WORD COUNT': 823, 'WORD COUNT': 857, 'SYLLABLE PER WORD': 2.093348891481914, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.847141190198366}
# 53
# {'URL_ID': 'blackassign0053', 'URL': 'https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/', 'POSITIVE SCORE': 12.166172106824925, 'NEGATIVE SCORE': 0.8902077151335311, 'POLARITY SCORE': 0.8636362974896745, 'SUBJECTIVITY SCORE': 0.038742966715772965, 'AVG SENTENCE LENGTH': 337.0, 'PERCENTAGE OF COMPLEX WORDS': 97.62611275964392, 'FOG INDEX': 140.23, 'AVG NUMBER OF WORDS PER SENTENCE': 337.0, 'COMPLEX WORD COUNT': 329, 'WORD COUNT': 337, 'SYLLABLE PER WORD': 2.0979228486646884, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.014836795252226}
# 54
# {'URL_ID': 'blackassign0054', 'URL': 'https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/', 'POSITIVE SCORE': 2.380952380952381, 'NEGATIVE SCORE': 0.4761904761904762, 'POLARITY SCORE': 0.6666664333334149, 'SUBJECTIVITY SCORE': 0.013605442112082929, 'AVG SENTENCE LENGTH': 210.0, 'PERCENTAGE OF COMPLEX WORDS': 94.28571428571428, 'FOG INDEX': 46.27, 'AVG NUMBER OF WORDS PER SENTENCE': 210.0, 'COMPLEX WORD COUNT': 198, 'WORD COUNT': 210, 'SYLLABLE PER WORD': 1.7809523809523808, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.261904761904762}
# 55
# {'URL_ID': 'blackassign0055', 'URL': 'https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/', 'POSITIVE SCORE': 5.048859934853421, 'NEGATIVE SCORE': 1.4657980456026058, 'POLARITY SCORE': 0.549999915575013, 'SUBJECTIVITY SCORE': 0.010610192133299404, 'AVG SENTENCE LENGTH': 614.0, 'PERCENTAGE OF COMPLEX WORDS': 95.11400651465797, 'FOG INDEX': 63.97, 'AVG NUMBER OF WORDS PER SENTENCE': 614.0, 'COMPLEX WORD COUNT': 584, 'WORD COUNT': 614, 'SYLLABLE PER WORD': 1.8338762214983713, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.100977198697068}
# 56
# {'URL_ID': 'blackassign0056', 'URL': 'https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/', 'POSITIVE SCORE': 7.042253521126761, 'NEGATIVE SCORE': 2.2535211267605635, 'POLARITY SCORE': 0.5151514597337067, 'SUBJECTIVITY SCORE': 0.026185280624512797, 'AVG SENTENCE LENGTH': 355.0, 'PERCENTAGE OF COMPLEX WORDS': 98.30985915492958, 'FOG INDEX': 150.37, 'AVG NUMBER OF WORDS PER SENTENCE': 355.0, 'COMPLEX WORD COUNT': 349, 'WORD COUNT': 355, 'SYLLABLE PER WORD': 2.1971830985915495, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.154929577464789}
# 57
# {'URL_ID': 'blackassign0057', 'URL': 'https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/', 'POSITIVE SCORE': 9.202453987730062, 'NEGATIVE SCORE': 4.9079754601226995, 'POLARITY SCORE': 0.30434780451795995, 'SUBJECTIVITY SCORE': 0.08656705129623135, 'AVG SENTENCE LENGTH': 163.0, 'PERCENTAGE OF COMPLEX WORDS': 97.54601226993866, 'FOG INDEX': 72.91, 'AVG NUMBER OF WORDS PER SENTENCE': 163.0, 'COMPLEX WORD COUNT': 159, 'WORD COUNT': 163, 'SYLLABLE PER WORD': 2.147239263803681, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.5030674846625764}
# 58
# {'URL_ID': 'blackassign0058', 'URL': 'https://insights.blackcoffer.com/how-we-forecast-future-technologies/', 'POSITIVE SCORE': 5.4945054945054945, 'NEGATIVE SCORE': 0.0, 'POLARITY SCORE': 0.9999998180000331, 'SUBJECTIVITY SCORE': 0.06037918059479466, 'AVG SENTENCE LENGTH': 91.0, 'PERCENTAGE OF COMPLEX WORDS': 100.0, 'FOG INDEX': 46.67, 'AVG NUMBER OF WORDS PER SENTENCE': 91.0, 'COMPLEX WORD COUNT': 91, 'WORD COUNT': 91, 'SYLLABLE PER WORD': 2.340659340659341, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.373626373626373}
# 59
# {'URL_ID': 'blackassign0059', 'URL': 'https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/', 'POSITIVE SCORE': 5.764411027568922, 'NEGATIVE SCORE': 9.022556390977442, 'POLARITY SCORE': -0.22033896814995788, 'SUBJECTIVITY SCORE': 0.037060068625278934, 'AVG SENTENCE LENGTH': 399.0, 'PERCENTAGE OF COMPLEX WORDS': 89.47368421052632, 'FOG INDEX': 149.19, 'AVG NUMBER OF WORDS PER SENTENCE': 399.0, 'COMPLEX WORD COUNT': 357, 'WORD COUNT': 399, 'SYLLABLE PER WORD': 1.7418546365914787, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 5.942355889724311}
# 60
# {'URL_ID': 'blackassign0060', 'URL': 'https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/', 'POSITIVE SCORE': 10.975609756097562, 'NEGATIVE SCORE': 2.4390243902439024, 'POLARITY SCORE': 0.6363635889256234, 'SUBJECTIVITY SCORE': 0.16359309735058986, 'AVG SENTENCE LENGTH': 82.0, 'PERCENTAGE OF COMPLEX WORDS': 97.5609756097561, 'FOG INDEX': 38.5, 'AVG NUMBER OF WORDS PER SENTENCE': 82.0, 'COMPLEX WORD COUNT': 80, 'WORD COUNT': 82, 'SYLLABLE PER WORD': 1.9390243902439024, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.548780487804878}
# 61
# {'URL_ID': 'blackassign0061', 'URL': 'https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/', 'POSITIVE SCORE': 7.453416149068323, 'NEGATIVE SCORE': 2.950310559006211, 'POLARITY SCORE': 0.43283577929160577, 'SUBJECTIVITY SCORE': 0.016154855111676518, 'AVG SENTENCE LENGTH': 644.0, 'PERCENTAGE OF COMPLEX WORDS': 97.82608695652173, 'FOG INDEX': 50.86, 'AVG NUMBER OF WORDS PER SENTENCE': 644.0, 'COMPLEX WORD COUNT': 630, 'WORD COUNT': 644, 'SYLLABLE PER WORD': 2.3027950310559007, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.537267080745342}
# 62
# {'URL_ID': 'blackassign0062', 'URL': 'https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/', 'POSITIVE SCORE': 3.7453183520599254, 'NEGATIVE SCORE': 6.741573033707865, 'POLARITY SCORE': -0.2857142584693903, 'SUBJECTIVITY SCORE': 0.03927674661607133, 'AVG SENTENCE LENGTH': 267.0, 'PERCENTAGE OF COMPLEX WORDS': 94.3820224719101, 'FOG INDEX': 16.96, 'AVG NUMBER OF WORDS PER SENTENCE': 267.0, 'COMPLEX WORD COUNT': 252, 'WORD COUNT': 267, 'SYLLABLE PER WORD': 2.0898876404494384, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.835205992509363}
# 63
# {'URL_ID': 'blackassign0063', 'URL': 'https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/', 'POSITIVE SCORE': 4.742268041237113, 'NEGATIVE SCORE': 7.628865979381444, 'POLARITY SCORE': -0.23333331447222377, 'SUBJECTIVITY SCORE': 0.025507492773424876, 'AVG SENTENCE LENGTH': 485.0, 'PERCENTAGE OF COMPLEX WORDS': 97.11340206185567, 'FOG INDEX': 100.54, 'AVG NUMBER OF WORDS PER SENTENCE': 485.0, 'COMPLEX WORD COUNT': 471, 'WORD COUNT': 485, 'SYLLABLE PER WORD': 2.0680412371134023, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.665979381443299}
# 64
# {'URL_ID': 'blackassign0064', 'URL': 'https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/', 'POSITIVE SCORE': 2.869757174392936, 'NEGATIVE SCORE': 5.408388520971302, 'POLARITY SCORE': -0.30666662962133784, 'SUBJECTIVITY SCORE': 0.009137026143738644, 'AVG SENTENCE LENGTH': 906.0, 'PERCENTAGE OF COMPLEX WORDS': 95.36423841059603, 'FOG INDEX': 355.12, 'AVG NUMBER OF WORDS PER SENTENCE': 906.0, 'COMPLEX WORD COUNT': 864, 'WORD COUNT': 906, 'SYLLABLE PER WORD': 2.1677704194260485, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.239514348785872}
# 65
# {'URL_ID': 'blackassign0065', 'URL': 'https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/', 'POSITIVE SCORE': 5.569948186528497, 'NEGATIVE SCORE': 2.9792746113989637, 'POLARITY SCORE': 0.3030302675849445, 'SUBJECTIVITY SCORE': 0.011074122780898105, 'AVG SENTENCE LENGTH': 772.0, 'PERCENTAGE OF COMPLEX WORDS': 97.15025906735751, 'FOG INDEX': 107.63, 'AVG NUMBER OF WORDS PER SENTENCE': 772.0, 'COMPLEX WORD COUNT': 750, 'WORD COUNT': 772, 'SYLLABLE PER WORD': 1.9287564766839378, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.544041450777202}
# 66
# {'URL_ID': 'blackassign0066', 'URL': 'https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/', 'POSITIVE SCORE': 4.644808743169399, 'NEGATIVE SCORE': 3.551912568306011, 'POLARITY SCORE': 0.13333331706666868, 'SUBJECTIVITY SCORE': 0.011197706694368448, 'AVG SENTENCE LENGTH': 732.0, 'PERCENTAGE OF COMPLEX WORDS': 96.44808743169399, 'FOG INDEX': 100.56, 'AVG NUMBER OF WORDS PER SENTENCE': 732.0, 'COMPLEX WORD COUNT': 706, 'WORD COUNT': 732, 'SYLLABLE PER WORD': 1.855191256830601, 'PERSONAL PRONOUNS': {'i': 0, 'we': 2, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.41120218579235}
# 67
# {'URL_ID': 'blackassign0067', 'URL': 'https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/', 'POSITIVE SCORE': 6.775067750677506, 'NEGATIVE SCORE': 1.8970189701897018, 'POLARITY SCORE': 0.5624999351367262, 'SUBJECTIVITY SCORE': 0.023501589965760482, 'AVG SENTENCE LENGTH': 369.0, 'PERCENTAGE OF COMPLEX WORDS': 94.579945799458, 'FOG INDEX': 147.16, 'AVG NUMBER OF WORDS PER SENTENCE': 369.0, 'COMPLEX WORD COUNT': 349, 'WORD COUNT': 369, 'SYLLABLE PER WORD': 1.937669376693767, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.536585365853658}
# 68
# {'URL_ID': 'blackassign0068', 'URL': 'https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/', 'POSITIVE SCORE': 7.032590051457976, 'NEGATIVE SCORE': 1.3722126929674099, 'POLARITY SCORE': 0.6734693076259989, 'SUBJECTIVITY SCORE': 0.014416471235006714, 'AVG SENTENCE LENGTH': 583.0, 'PERCENTAGE OF COMPLEX WORDS': 90.56603773584906, 'FOG INDEX': 113.1, 'AVG NUMBER OF WORDS PER SENTENCE': 583.0, 'COMPLEX WORD COUNT': 528, 'WORD COUNT': 583, 'SYLLABLE PER WORD': 1.8885077186963979, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.360205831903945}
# 69
# {'URL_ID': 'blackassign0069', 'URL': 'https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/', 'POSITIVE SCORE': 15.07537688442211, 'NEGATIVE SCORE': 3.015075376884422, 'POLARITY SCORE': 0.6666666298148168, 'SUBJECTIVITY SCORE': 0.09090679482612933, 'AVG SENTENCE LENGTH': 199.0, 'PERCENTAGE OF COMPLEX WORDS': 92.46231155778895, 'FOG INDEX': 45.56, 'AVG NUMBER OF WORDS PER SENTENCE': 199.0, 'COMPLEX WORD COUNT': 184, 'WORD COUNT': 199, 'SYLLABLE PER WORD': 2.020100502512563, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.49748743718593}
# 70
# {'URL_ID': 'blackassign0070', 'URL': 'https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/', 'POSITIVE SCORE': 4.723502304147465, 'NEGATIVE SCORE': 1.8433179723502304, 'POLARITY SCORE': 0.4385964244382988, 'SUBJECTIVITY SCORE': 0.007565461139322851, 'AVG SENTENCE LENGTH': 868.0, 'PERCENTAGE OF COMPLEX WORDS': 94.35483870967742, 'FOG INDEX': 73.27, 'AVG NUMBER OF WORDS PER SENTENCE': 868.0, 'COMPLEX WORD COUNT': 819, 'WORD COUNT': 868, 'SYLLABLE PER WORD': 2.0276497695852536, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.733870967741935}
# 71
# {'URL_ID': 'blackassign0071', 'URL': 'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/', 'POSITIVE SCORE': 4.956896551724138, 'NEGATIVE SCORE': 15.517241379310345, 'POLARITY SCORE': -0.515789448491968, 'SUBJECTIVITY SCORE': 0.0441252971700629, 'AVG SENTENCE LENGTH': 464.0, 'PERCENTAGE OF COMPLEX WORDS': 89.22413793103449, 'FOG INDEX': 49.23, 'AVG NUMBER OF WORDS PER SENTENCE': 464.0, 'COMPLEX WORD COUNT': 414, 'WORD COUNT': 464, 'SYLLABLE PER WORD': 1.7974137931034482, 'PERSONAL PRONOUNS': {'i': 4, 'we': 2, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.191810344827586}
# 72
# {'URL_ID': 'blackassign0072', 'URL': 'https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/', 'POSITIVE SCORE': 11.786372007366483, 'NEGATIVE SCORE': 4.051565377532229, 'POLARITY SCORE': 0.48837206218767093, 'SUBJECTIVITY SCORE': 0.029167472110002285, 'AVG SENTENCE LENGTH': 543.0, 'PERCENTAGE OF COMPLEX WORDS': 93.73848987108656, 'FOG INDEX': 208.16, 'AVG NUMBER OF WORDS PER SENTENCE': 543.0, 'COMPLEX WORD COUNT': 509, 'WORD COUNT': 543, 'SYLLABLE PER WORD': 1.7679558011049723, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.064456721915286}
# 73
# {'URL_ID': 'blackassign0073', 'URL': 'https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/', 'POSITIVE SCORE': 4.166666666666666, 'NEGATIVE SCORE': 7.098765432098765, 'POLARITY SCORE': -0.26027394949897004, 'SUBJECTIVITY SCORE': 0.017384926051513122, 'AVG SENTENCE LENGTH': 648.0, 'PERCENTAGE OF COMPLEX WORDS': 97.22222222222221, 'FOG INDEX': 22.74, 'AVG NUMBER OF WORDS PER SENTENCE': 648.0, 'COMPLEX WORD COUNT': 630, 'WORD COUNT': 648, 'SYLLABLE PER WORD': 1.816358024691358, 'PERSONAL PRONOUNS': {'i': 2, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.296296296296297}
# 74
# {'URL_ID': 'blackassign0074', 'URL': 'https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/', 'POSITIVE SCORE': 4.057591623036649, 'NEGATIVE SCORE': 3.4031413612565444, 'POLARITY SCORE': 0.0877192864881518, 'SUBJECTIVITY SCORE': 0.009765357296502403, 'AVG SENTENCE LENGTH': 764.0, 'PERCENTAGE OF COMPLEX WORDS': 95.81151832460732, 'FOG INDEX': 34.69, 'AVG NUMBER OF WORDS PER SENTENCE': 764.0, 'COMPLEX WORD COUNT': 732, 'WORD COUNT': 764, 'SYLLABLE PER WORD': 2.1793193717277486, 'PERSONAL PRONOUNS': {'i': 1, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.928010471204188}
# 75
# {'URL_ID': 'blackassign0075', 'URL': 'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/', 'POSITIVE SCORE': 4.665314401622718, 'NEGATIVE SCORE': 16.227180527383368, 'POLARITY SCORE': -0.5533980317645408, 'SUBJECTIVITY SCORE': 0.042378285774092896, 'AVG SENTENCE LENGTH': 493.0, 'PERCENTAGE OF COMPLEX WORDS': 89.4523326572008, 'FOG INDEX': 52.19, 'AVG NUMBER OF WORDS PER SENTENCE': 493.0, 'COMPLEX WORD COUNT': 441, 'WORD COUNT': 493, 'SYLLABLE PER WORD': 1.8133874239350913, 'PERSONAL PRONOUNS': {'i': 4, 'we': 3, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.253549695740365}
# 76
# {'URL_ID': 'blackassign0076', 'URL': 'https://insights.blackcoffer.com/how-small-business-can-survive-the-coronavirus-crisis/', 'POSITIVE SCORE': 5.376344086021505, 'NEGATIVE SCORE': 4.435483870967742, 'POLARITY SCORE': 0.09589040118596455, 'SUBJECTIVITY SCORE': 0.013187940784679176, 'AVG SENTENCE LENGTH': 744.0, 'PERCENTAGE OF COMPLEX WORDS': 96.7741935483871, 'FOG INDEX': 26.9, 'AVG NUMBER OF WORDS PER SENTENCE': 744.0, 'COMPLEX WORD COUNT': 720, 'WORD COUNT': 744, 'SYLLABLE PER WORD': 1.9448924731182795, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.51747311827957}
# 77
# {'URL_ID': 'blackassign0077', 'URL': 'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/', 'POSITIVE SCORE': 5.989583333333334, 'NEGATIVE SCORE': 3.3854166666666665, 'POLARITY SCORE': 0.2777777481481514, 'SUBJECTIVITY SCORE': 0.02441406243642171, 'AVG SENTENCE LENGTH': 384.0, 'PERCENTAGE OF COMPLEX WORDS': 99.73958333333334, 'FOG INDEX': 37.85, 'AVG NUMBER OF WORDS PER SENTENCE': 384.0, 'COMPLEX WORD COUNT': 383, 'WORD COUNT': 384, 'SYLLABLE PER WORD': 2.1536458333333335, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.174479166666667}
# 78
# {'URL_ID': 'blackassign0078', 'URL': 'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/', 'POSITIVE SCORE': 5.77223088923557, 'NEGATIVE SCORE': 3.9001560062402496, 'POLARITY SCORE': 0.19354836708637052, 'SUBJECTIVITY SCORE': 0.015089527114487196, 'AVG SENTENCE LENGTH': 641.0, 'PERCENTAGE OF COMPLEX WORDS': 98.12792511700468, 'FOG INDEX': 58.27, 'AVG NUMBER OF WORDS PER SENTENCE': 641.0, 'COMPLEX WORD COUNT': 629, 'WORD COUNT': 641, 'SYLLABLE PER WORD': 2.1201248049921997, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.179407176287051}
# 79
# {'URL_ID': 'blackassign0079', 'URL': 'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/', 'POSITIVE SCORE': 3.8461538461538463, 'NEGATIVE SCORE': 5.944055944055944, 'POLARITY SCORE': -0.21428569239796144, 'SUBJECTIVITY SCORE': 0.01141050090769148, 'AVG SENTENCE LENGTH': 858.0, 'PERCENTAGE OF COMPLEX WORDS': 96.5034965034965, 'FOG INDEX': 44.02, 'AVG NUMBER OF WORDS PER SENTENCE': 858.0, 'COMPLEX WORD COUNT': 828, 'WORD COUNT': 858, 'SYLLABLE PER WORD': 1.9627039627039626, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.773892773892774}
# 80
# {'URL_ID': 'blackassign0080', 'URL': 'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/', 'POSITIVE SCORE': 1.6363636363636365, 'NEGATIVE SCORE': 0.5454545454545455, 'POLARITY SCORE': 0.4999997708334382, 'SUBJECTIVITY SCORE': 0.000991735536739294, 'AVG SENTENCE LENGTH': 2200.0, 'PERCENTAGE OF COMPLEX WORDS': 93.18181818181817, 'FOG INDEX': 119.66, 'AVG NUMBER OF WORDS PER SENTENCE': 2200.0, 'COMPLEX WORD COUNT': 2050, 'WORD COUNT': 2200, 'SYLLABLE PER WORD': 1.625909090909091, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 5.880909090909091}
# 81
# {'URL_ID': 'blackassign0081', 'URL': 'https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/', 'POSITIVE SCORE': 4.3478260869565215, 'NEGATIVE SCORE': 5.7579318448883665, 'POLARITY SCORE': -0.13953486991346814, 'SUBJECTIVITY SCORE': 0.011875156192678886, 'AVG SENTENCE LENGTH': 851.0, 'PERCENTAGE OF COMPLEX WORDS': 96.94477085781433, 'FOG INDEX': 337.61, 'AVG NUMBER OF WORDS PER SENTENCE': 851.0, 'COMPLEX WORD COUNT': 825, 'WORD COUNT': 851, 'SYLLABLE PER WORD': 2.016451233842538, 'PERSONAL PRONOUNS': {'i': 0, 'we': 5, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.866039952996474}
# 82
# {'URL_ID': 'blackassign0082', 'URL': 'https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/', 'POSITIVE SCORE': 3.4482758620689653, 'NEGATIVE SCORE': 8.204518430439952, 'POLARITY SCORE': -0.40816323027905344, 'SUBJECTIVITY SCORE': 0.013855879047149869, 'AVG SENTENCE LENGTH': 841.0, 'PERCENTAGE OF COMPLEX WORDS': 99.28656361474435, 'FOG INDEX': 91.95, 'AVG NUMBER OF WORDS PER SENTENCE': 841.0, 'COMPLEX WORD COUNT': 835, 'WORD COUNT': 841, 'SYLLABLE PER WORD': 2.1236623067776454, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.19500594530321}
# 83
# {'URL_ID': 'blackassign0083', 'URL': 'https://insights.blackcoffer.com/human-rights-outlook/', 'POSITIVE SCORE': 3.9473684210526314, 'NEGATIVE SCORE': 3.9473684210526314, 'POLARITY SCORE': 0.0, 'SUBJECTIVITY SCORE': 0.103878114976673, 'AVG SENTENCE LENGTH': 76.0, 'PERCENTAGE OF COMPLEX WORDS': 94.73684210526315, 'FOG INDEX': 36.02, 'AVG NUMBER OF WORDS PER SENTENCE': 76.0, 'COMPLEX WORD COUNT': 72, 'WORD COUNT': 76, 'SYLLABLE PER WORD': 1.855263157894737, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.434210526315789}
# 84
# {'URL_ID': 'blackassign0084', 'URL': 'https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/', 'POSITIVE SCORE': 6.5009560229445515, 'NEGATIVE SCORE': 0.7648183556405354, 'POLARITY SCORE': 0.7894735755540315, 'SUBJECTIVITY SCORE': 0.013892494005148363, 'AVG SENTENCE LENGTH': 523.0, 'PERCENTAGE OF COMPLEX WORDS': 87.38049713193116, 'FOG INDEX': 51.41, 'AVG NUMBER OF WORDS PER SENTENCE': 523.0, 'COMPLEX WORD COUNT': 457, 'WORD COUNT': 523, 'SYLLABLE PER WORD': 1.6233269598470363, 'PERSONAL PRONOUNS': {'i': 0, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 5.835564053537285}
# 85
# {'URL_ID': 'blackassign0085', 'URL': 'https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/', 'POSITIVE SCORE': 5.291723202170964, 'NEGATIVE SCORE': 4.477611940298507, 'POLARITY SCORE': 0.0833333248032417, 'SUBJECTIVITY SCORE': 0.013255542916165437, 'AVG SENTENCE LENGTH': 737.0, 'PERCENTAGE OF COMPLEX WORDS': 98.10040705563094, 'FOG INDEX': 297.28, 'AVG NUMBER OF WORDS PER SENTENCE': 737.0, 'COMPLEX WORD COUNT': 723, 'WORD COUNT': 737, 'SYLLABLE PER WORD': 2.1953867028493894, 'PERSONAL PRONOUNS': {'i': 0, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.175033921302578}
# 86
# {'URL_ID': 'blackassign0086', 'URL': 'https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/', 'POSITIVE SCORE': 5.832449628844114, 'NEGATIVE SCORE': 1.6967126193001063, 'POLARITY SCORE': 0.5492957016921343, 'SUBJECTIVITY SCORE': 0.007984265366023282, 'AVG SENTENCE LENGTH': 943.0, 'PERCENTAGE OF COMPLEX WORDS': 91.72852598091198, 'FOG INDEX': 122.47, 'AVG NUMBER OF WORDS PER SENTENCE': 943.0, 'COMPLEX WORD COUNT': 865, 'WORD COUNT': 943, 'SYLLABLE PER WORD': 1.8791092258748674, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.465535524920466}
# 87
# {'URL_ID': 'blackassign0087', 'URL': 'https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/', 'POSITIVE SCORE': 5.565862708719852, 'NEGATIVE SCORE': 6.122448979591836, 'POLARITY SCORE': -0.04761904354497385, 'SUBJECTIVITY SCORE': 0.021685179344390557, 'AVG SENTENCE LENGTH': 539.0, 'PERCENTAGE OF COMPLEX WORDS': 97.40259740259741, 'FOG INDEX': 217.47, 'AVG NUMBER OF WORDS PER SENTENCE': 539.0, 'COMPLEX WORD COUNT': 525, 'WORD COUNT': 539, 'SYLLABLE PER WORD': 1.966604823747681, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.7309833024118735}
# 88
# {'URL_ID': 'blackassign0088', 'URL': 'https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/', 'POSITIVE SCORE': 1.691542288557214, 'NEGATIVE SCORE': 4.378109452736319, 'POLARITY SCORE': -0.44262287789573906, 'SUBJECTIVITY SCORE': 0.006039454462939381, 'AVG SENTENCE LENGTH': 1005.0, 'PERCENTAGE OF COMPLEX WORDS': 98.40796019900498, 'FOG INDEX': 29.96, 'AVG NUMBER OF WORDS PER SENTENCE': 1005.0, 'COMPLEX WORD COUNT': 989, 'WORD COUNT': 1005, 'SYLLABLE PER WORD': 2.1124378109452735, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.900497512437811}
# 89
# {'URL_ID': 'blackassign0089', 'URL': 'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/', 'POSITIVE SCORE': 3.4343434343434343, 'NEGATIVE SCORE': 8.484848484848486, 'POLARITY SCORE': -0.42372877800919584, 'SUBJECTIVITY SCORE': 0.024079175545682313, 'AVG SENTENCE LENGTH': 495.0, 'PERCENTAGE OF COMPLEX WORDS': 97.17171717171718, 'FOG INDEX': 39.33, 'AVG NUMBER OF WORDS PER SENTENCE': 495.0, 'COMPLEX WORD COUNT': 481, 'WORD COUNT': 495, 'SYLLABLE PER WORD': 2.0343434343434343, 'PERSONAL PRONOUNS': {'i': 2, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.806060606060606}
# 90
# {'URL_ID': 'blackassign0090', 'URL': 'https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/', 'POSITIVE SCORE': 6.7924528301886795, 'NEGATIVE SCORE': 8.867924528301886, 'POLARITY SCORE': -0.13253011201916148, 'SUBJECTIVITY SCORE': 0.029547881752722046, 'AVG SENTENCE LENGTH': 530.0, 'PERCENTAGE OF COMPLEX WORDS': 98.11320754716981, 'FOG INDEX': 216.15, 'AVG NUMBER OF WORDS PER SENTENCE': 530.0, 'COMPLEX WORD COUNT': 520, 'WORD COUNT': 530, 'SYLLABLE PER WORD': 2.0245283018867926, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.850943396226415}
# 91
# {'URL_ID': 'blackassign0091', 'URL': 'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/', 'POSITIVE SCORE': 4.590818363273453, 'NEGATIVE SCORE': 5.389221556886228, 'POLARITY SCORE': -0.07999999198400089, 'SUBJECTIVITY SCORE': 0.01992023932183521, 'AVG SENTENCE LENGTH': 501.0, 'PERCENTAGE OF COMPLEX WORDS': 98.20359281437125, 'FOG INDEX': 58.24, 'AVG NUMBER OF WORDS PER SENTENCE': 501.0, 'COMPLEX WORD COUNT': 492, 'WORD COUNT': 501, 'SYLLABLE PER WORD': 2.1357285429141717, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.984031936127744}
# 92
# {'URL_ID': 'blackassign0092', 'URL': 'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/', 'POSITIVE SCORE': 2.813299232736573, 'NEGATIVE SCORE': 5.754475703324808, 'POLARITY SCORE': -0.34328354202272693, 'SUBJECTIVITY SCORE': 0.0109562339195718, 'AVG SENTENCE LENGTH': 782.0, 'PERCENTAGE OF COMPLEX WORDS': 94.37340153452686, 'FOG INDEX': 32.07, 'AVG NUMBER OF WORDS PER SENTENCE': 782.0, 'COMPLEX WORD COUNT': 738, 'WORD COUNT': 782, 'SYLLABLE PER WORD': 1.8989769820971867, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 1}, 'AVG WORD LENGTH': 6.565217391304348}
# 93
# {'URL_ID': 'blackassign0093', 'URL': 'https://insights.blackcoffer.com/travel-and-tourism-outlook/', 'POSITIVE SCORE': 4.705882352941177, 'NEGATIVE SCORE': 3.5294117647058822, 'POLARITY SCORE': 0.14285712551020624, 'SUBJECTIVITY SCORE': 0.09688581200895584, 'AVG SENTENCE LENGTH': 85.0, 'PERCENTAGE OF COMPLEX WORDS': 95.29411764705881, 'FOG INDEX': 38.33, 'AVG NUMBER OF WORDS PER SENTENCE': 85.0, 'COMPLEX WORD COUNT': 81, 'WORD COUNT': 85, 'SYLLABLE PER WORD': 1.7176470588235293, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.08235294117647}
# 94
# {'URL_ID': 'blackassign0094', 'URL': 'https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/', 'POSITIVE SCORE': 5.414551607445008, 'NEGATIVE SCORE': 8.121827411167512, 'POLARITY SCORE': -0.19999998522500106, 'SUBJECTIVITY SCORE': 0.02290419457818668, 'AVG SENTENCE LENGTH': 591.0, 'PERCENTAGE OF COMPLEX WORDS': 94.585448392555, 'FOG INDEX': 83.04, 'AVG NUMBER OF WORDS PER SENTENCE': 591.0, 'COMPLEX WORD COUNT': 559, 'WORD COUNT': 591, 'SYLLABLE PER WORD': 1.8460236886632826, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.328257191201353}
# 95
# {'URL_ID': 'blackassign0095', 'URL': 'https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/', 'POSITIVE SCORE': 2.2988505747126435, 'NEGATIVE SCORE': 7.183908045977011, 'POLARITY SCORE': -0.515151460826452, 'SUBJECTIVITY SCORE': 0.027249306302989506, 'AVG SENTENCE LENGTH': 348.0, 'PERCENTAGE OF COMPLEX WORDS': 96.83908045977012, 'FOG INDEX': 39.87, 'AVG NUMBER OF WORDS PER SENTENCE': 348.0, 'COMPLEX WORD COUNT': 337, 'WORD COUNT': 348, 'SYLLABLE PER WORD': 1.8448275862068966, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.416666666666667}
# 96
# {'URL_ID': 'blackassign0096', 'URL': 'https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/', 'POSITIVE SCORE': 4.753820033955857, 'NEGATIVE SCORE': 9.67741935483871, 'POLARITY SCORE': -0.3411764469467145, 'SUBJECTIVITY SCORE': 0.024501255287424976, 'AVG SENTENCE LENGTH': 589.0, 'PERCENTAGE OF COMPLEX WORDS': 98.47198641765704, 'FOG INDEX': 86.63, 'AVG NUMBER OF WORDS PER SENTENCE': 589.0, 'COMPLEX WORD COUNT': 580, 'WORD COUNT': 589, 'SYLLABLE PER WORD': 2.1697792869269947, 'PERSONAL PRONOUNS': {'i': 2, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.183361629881155}
# 97
# {'URL_ID': 'blackassign0097', 'URL': 'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/', 'POSITIVE SCORE': 4.932735426008969, 'NEGATIVE SCORE': 7.847533632286996, 'POLARITY SCORE': -0.22807015759310706, 'SUBJECTIVITY SCORE': 0.028655311725651687, 'AVG SENTENCE LENGTH': 446.0, 'PERCENTAGE OF COMPLEX WORDS': 95.51569506726457, 'FOG INDEX': 91.68, 'AVG NUMBER OF WORDS PER SENTENCE': 446.0, 'COMPLEX WORD COUNT': 426, 'WORD COUNT': 446, 'SYLLABLE PER WORD': 1.946188340807175, 'PERSONAL PRONOUNS': {'i': 1, 'we': 1, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.477578475336323}
# 98
# {'URL_ID': 'blackassign0098', 'URL': 'https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/', 'POSITIVE SCORE': 2.05761316872428, 'NEGATIVE SCORE': 1.2345679012345678, 'POLARITY SCORE': 0.24999992406252305, 'SUBJECTIVITY SCORE': 0.013548070190990854, 'AVG SENTENCE LENGTH': 243.0, 'PERCENTAGE OF COMPLEX WORDS': 96.70781893004116, 'FOG INDEX': 15.74, 'AVG NUMBER OF WORDS PER SENTENCE': 243.0, 'COMPLEX WORD COUNT': 235, 'WORD COUNT': 243, 'SYLLABLE PER WORD': 2.0864197530864197, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 7.02880658436214}
# 99
# {'URL_ID': 'blackassign0099', 'URL': 'https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/', 'POSITIVE SCORE': 5.263157894736842, 'NEGATIVE SCORE': 0.9868421052631579, 'POLARITY SCORE': 0.6842104168421228, 'SUBJECTIVITY SCORE': 0.020559210458686805, 'AVG SENTENCE LENGTH': 304.0, 'PERCENTAGE OF COMPLEX WORDS': 98.68421052631578, 'FOG INDEX': 45.36, 'AVG NUMBER OF WORDS PER SENTENCE': 304.0, 'COMPLEX WORD COUNT': 300, 'WORD COUNT': 304, 'SYLLABLE PER WORD': 1.8223684210526316, 'PERSONAL PRONOUNS': {'i': 0, 'we': 0, 'my': 0, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.2006578947368425}
# 100
# {'URL_ID': 'blackassign0100', 'URL': 'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/', 'POSITIVE SCORE': 5.729166666666666, 'NEGATIVE SCORE': 10.069444444444445, 'POLARITY SCORE': -0.27472525733607167, 'SUBJECTIVITY SCORE': 0.02742814424250515, 'AVG SENTENCE LENGTH': 576.0, 'PERCENTAGE OF COMPLEX WORDS': 93.40277777777779, 'FOG INDEX': 62.93, 'AVG NUMBER OF WORDS PER SENTENCE': 576.0, 'COMPLEX WORD COUNT': 538, 'WORD COUNT': 576, 'SYLLABLE PER WORD': 2.0729166666666665, 'PERSONAL PRONOUNS': {'i': 0, 'we': 1, 'my': 1, 'ours': 0, 'us': 0}, 'AVG WORD LENGTH': 6.934027777777778}
# Data saved to new_data.xlsx
